# %% [markdown]
# <a href="https://colab.research.google.com/github/DomcoSF/Pandas_Learning/blob/main/order.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_produto = pd.read_csv('/content/produto.csv')
df_produto
# Out:
#         descItem  vlPreco
# 0        abacate     5.25
# 1        abacaxi     2.50
# 2      abobrinha     2.00
# 3      alcaparra     3.00
# 4           alho     1.00
# ..           ...      ...
# 80        tomate     1.50
# 81   tomate seco     6.25
# 82     uva passa     3.75
# 83   vinho tinto    12.00
# 84  água com gás     5.00
#
# [85 rows x 2 columns]

# %%
df_produto.sort_values(by='vlPreco', ascending=False)
# Out:
#              descItem  vlPreco
# 43     massa integral    13.75
# 42       massa grossa    12.00
# 83        vinho tinto    12.00
# 62        queijo brie    11.25
# 64      queijo coalho    10.50
# ..                ...      ...
# 49            orégano     1.00
# 4                alho     1.00
# 74           salsinha     1.00
# 25          cebolinha     1.00
# 15  borda tradicional     0.00
#
# [85 rows x 2 columns]

# %%
df_produto.sort_values(by=['vlPreco','descItem'], ascending=[False,True])
# Out:
#              descItem  vlPreco
# 43     massa integral    13.75
# 42       massa grossa    12.00
# 83        vinho tinto    12.00
# 62        queijo brie    11.25
# 64      queijo coalho    10.50
# ..                ...      ...
# 4                alho     1.00
# 25          cebolinha     1.00
# 49            orégano     1.00
# 74           salsinha     1.00
# 15  borda tradicional     0.00
#
# [85 rows x 2 columns]
