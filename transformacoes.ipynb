# %% [markdown]
# <a href="https://colab.research.google.com/github/DomcoSF/Pandas_Learning/blob/main/transformacoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/produto.csv')
df
# Out:
#         descItem  vlPreco
# 0        abacate     5.25
# 1        abacaxi     2.50
# 2      abobrinha     2.00
# 3      alcaparra     3.00
# 4           alho     1.00
# ..           ...      ...
# 80        tomate     1.50
# 81   tomate seco     6.25
# 82     uva passa     3.75
# 83   vinho tinto    12.00
# 84  água com gás     5.00
#
# [85 rows x 2 columns]

# %%
df['precoAjustado'] = (df['vlPreco'] * 1.09).round(2)
df
# Out:
#         descItem  vlPreco  precoAjustado
# 0        abacate     5.25           5.72
# 1        abacaxi     2.50           2.72
# 2      abobrinha     2.00           2.18
# 3      alcaparra     3.00           3.27
# 4           alho     1.00           1.09
# ..           ...      ...            ...
# 80        tomate     1.50           1.64
# 81   tomate seco     6.25           6.81
# 82     uva passa     3.75           4.09
# 83   vinho tinto    12.00          13.08
# 84  água com gás     5.00           5.45
#
# [85 rows x 3 columns]

# %%
df['txtAjuste(%)'] = (100 * (df['precoAjustado'] / df['vlPreco'] - 1)).round(2)
df
# Out:
#         descItem  vlPreco  precoAjustado  txtAjuste(%)
# 0        abacate     5.25           5.72          8.95
# 1        abacaxi     2.50           2.72          8.80
# 2      abobrinha     2.00           2.18          9.00
# 3      alcaparra     3.00           3.27          9.00
# 4           alho     1.00           1.09          9.00
# ..           ...      ...            ...           ...
# 80        tomate     1.50           1.64          9.33
# 81   tomate seco     6.25           6.81          8.96
# 82     uva passa     3.75           4.09          9.07
# 83   vinho tinto    12.00          13.08          9.00
# 84  água com gás     5.00           5.45          9.00
#
# [85 rows x 4 columns]

# %%
#df = df.drop(columns = ["txtAjuste"])
#df

# %%
df['txtAjuste(%)']
df
# Out:
#         descItem  vlPreco  precoAjustado  txtAjuste(%)
# 0        abacate     5.25           5.72          8.95
# 1        abacaxi     2.50           2.72          8.80
# 2      abobrinha     2.00           2.18          9.00
# 3      alcaparra     3.00           3.27          9.00
# 4           alho     1.00           1.09          9.00
# ..           ...      ...            ...           ...
# 80        tomate     1.50           1.64          9.33
# 81   tomate seco     6.25           6.81          8.96
# 82     uva passa     3.75           4.09          9.07
# 83   vinho tinto    12.00          13.08          9.00
# 84  água com gás     5.00           5.45          9.00
#
# [85 rows x 4 columns]

# %%
def calcular(x):
  total = 1
  for i in range(2,int(x)+1):
    total *= i
  return total

# %%
df['precoAjustado'].apply(calcular)
# Out:
# 0            120
# 1              2
# 2              2
# 3              6
# 4              1
#          ...
# 80             1
# 81           720
# 82            24
# 83    6227020800
# 84           120
# Name: precoAjustado, Length: 85, dtype: int64

# %%
df
# Out:
#         descItem  vlPreco  precoAjustado  txtAjuste(%)
# 0        abacate     5.25           5.72          8.95
# 1        abacaxi     2.50           2.72          8.80
# 2      abobrinha     2.00           2.18          9.00
# 3      alcaparra     3.00           3.27          9.00
# 4           alho     1.00           1.09          9.00
# ..           ...      ...            ...           ...
# 80        tomate     1.50           1.64          9.33
# 81   tomate seco     6.25           6.81          8.96
# 82     uva passa     3.75           4.09          9.07
# 83   vinho tinto    12.00          13.08          9.00
# 84  água com gás     5.00           5.45          9.00
#
# [85 rows x 4 columns]
