# %% [markdown]
# <a href="https://colab.research.google.com/github/DomcoSF/Pandas_Learning/blob/main/dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    "nome": ["Teste1","Teste2","Teste3","Teste4","Teste5","Teste6","Teste7"],
    "idade": [30,33,2,45,65,43,46],
    "cor": ["Preto","Verde","Azul","Vermelho","Amarelo","Verde","Amarelo"]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#      nome  idade       cor
# 0  Teste1     30     Preto
# 1  Teste2     33     Verde
# 2  Teste3      2      Azul
# 3  Teste4     45  Vermelho
# 4  Teste5     65   Amarelo
# 5  Teste6     43     Verde
# 6  Teste7     46   Amarelo

# %%
df['idade']
# Out:
# 0    30
# 1    33
# 2     2
# 3    45
# 4    65
# 5    43
# 6    46
# Name: idade, dtype: int64

# %%
df.mean()
# Out:
# <ipython-input-9-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# idade    37.714286
# dtype: float64

# %%
df.describe()
# Out:
#            idade
# count   7.000000
# mean   37.714286
# std    19.371063
# min     2.000000
# 25%    31.500000
# 50%    43.000000
# 75%    45.500000
# max    65.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, sort_ascending=False, figscale=1):
#   from matplotlib import pyplot as plt
#   figsize = (8 * figscale, 4 * figscale)
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['idade'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# ...

# %%
df[['idade']].describe()
# Out:
#            idade
# count   7.000000
# mean   37.714286
# std    19.371063
# min     2.000000
# 25%    31.500000
# 50%    43.000000
# 75%    45.500000
# max    65.000000
