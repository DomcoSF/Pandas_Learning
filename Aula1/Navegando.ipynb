# %% [markdown]
# <a href="https://colab.research.google.com/github/DomcoSF/Pandas_Learning/blob/main/Navegando.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/pedido.csv')

# %%
df
# Out:
#       idPedido                      dtPedido flKetchup             descUF  \
# 0            0  2023-05-11T10:59:33.000+0000       NaN              Goiás
# 1            1  2023-05-11T11:23:42.000+0000       NaN             Paraná
# 2            2  2023-05-11T11:24:29.000+0000       NaN          São Paulo
# 3            3  2023-05-11T11:29:39.000+0000       NaN          São Paulo
# 4            4  2023-05-11T11:31:30.000+0000       NaN  Rio Grande do Sul
# ...        ...                           ...       ...                ...
# 1101      1101  2023-05-25T16:47:40.000+0000      True            Sergipe
# 1102      1102  2023-05-25T16:55:35.000+0000     False          São Paulo
# 1103      1103  2023-05-25T17:07:05.000+0000     False          São Paulo
# 1104      1104  2023-05-25T18:18:02.000+0000      True          São Paulo
# 1105      1105  2023-05-25T18:27:12.000+0000     False          São Paulo
#
#                                               txtRecado
# ...

# %%
colunas = ['idPedido','flKetchup'] # df[['idPedido', 'flKetchup']]
df[colunas]
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py:700: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# /usr/local/lib/python3.10/dist-packages/google/colab/_interactive_table_hint_button.py:162: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_html=dataframe._repr_html_(),
#       idPedido flKetchup
# 0            0       NaN
# 1            1       NaN
# 2            2       NaN
# 3            3       NaN
# 4            4       NaN
# ...        ...       ...
# 1101      1101      True
# 1102      1102     False
# 1103      1103     False
# 1104      1104      True
# 1105      1105     False
#
# [1106 rows x 2 columns]

# %%
df_sample = df.sample(100)
df_sample
# Out:
#      idPedido                      dtPedido flKetchup             descUF  \
# 854       854  2023-05-24T17:02:15.000+0000     False       Minas Gerais
# 796       796  2023-05-24T15:34:33.000+0000      True             Paraná
# 117       117  2023-05-14T08:08:52.000+0000     False          São Paulo
# 882       882  2023-05-24T17:35:56.000+0000     False  Rio Grande do Sul
# 359       359  2023-05-23T09:35:09.000+0000     False          São Paulo
# ..        ...                           ...       ...                ...
# 235       235  2023-05-17T13:15:41.000+0000     False          São Paulo
# 671       671  2023-05-24T14:14:23.000+0000     False       Minas Gerais
# 990       990  2023-05-24T20:09:13.000+0000     False          São Paulo
# 297       297  2023-05-22T01:07:02.000+0000     False        Mato Grosso
# 476       476  2023-05-23T19:16:40.000+0000     False          São Paulo
#
#                                              txtRecado
# ...

# %%
df_sample.iloc[0:4]
# Out:
#      idPedido                      dtPedido flKetchup             descUF  \
# 854       854  2023-05-24T17:02:15.000+0000     False       Minas Gerais
# 796       796  2023-05-24T15:34:33.000+0000      True             Paraná
# 117       117  2023-05-14T08:08:52.000+0000     False          São Paulo
# 882       882  2023-05-24T17:35:56.000+0000     False  Rio Grande do Sul
#
#                        txtRecado
# 854                          NaN
# 796                          NaN
# 117                          NaN
# 882  Quero cortada em 8 pedaços!

# %%
df_sample.iloc[[0,2,5]]
# Out:
#      idPedido                      dtPedido flKetchup          descUF  \
# 854       854  2023-05-24T17:02:15.000+0000     False    Minas Gerais
# 117       117  2023-05-14T08:08:52.000+0000     False       São Paulo
# 372       372  2023-05-23T09:51:14.000+0000     False  Rio de Janeiro
#
#                                              txtRecado
# 854                                                NaN
# 117                                                NaN
# 372  Pizza se come com a mão! Abraço do pessoal de ...

# %%
df_sample.iloc[0:4][['idPedido','dtPedido']]
# Out:
#      idPedido                      dtPedido
# 854       854  2023-05-24T17:02:15.000+0000
# 796       796  2023-05-24T15:34:33.000+0000
# 117       117  2023-05-14T08:08:52.000+0000
# 882       882  2023-05-24T17:35:56.000+0000
